# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
#画像表示関数
def  display(data) :
    fig, ax = plt.subplots()
    ax.imshow(data, cmap='binary_r')
    plt.show()    

#DFT関数
def dft(data) :
    #2 次元高速フーリエ変換で周波数領域の情報を取り出す
    f_uv = np.fft.fft2(data)
    
    # 画像の中心に低周波数の成分がくるように並べかえる
    shifted_f_uv = np.fft.fftshift(f_uv)
    
    # パワースペクトルに変換する
    np.seterr(divide = 'ignore')
    magnitude_spectrum2d =  np.absolute(shifted_f_uv) #np.log 
    magnitude_spectrum2d *= (255.0/magnitude_spectrum2d.max())
    return magnitude_spectrum2d

# %%
data = np.zeros([8,8])
data[0::2] = 1

#画像表示
display(data)

# %%
#パワースペクトル画像表示
display(dft(data))

# %%
data = np.zeros([8,8])
data[1::2] = 1

#画像表示
display(data)

# %%
#パワースペクトル画像表示
display(dft(data))

# %%
data = np.zeros([8,8])
data[:,::2] = 1

#画像表示
display(data)

# %%
#パワースペクトル画像表示
display(dft(data))

# %%
sample = np.zeros([4,4])
sample[0::2]=1
data = np.zeros([8,8])
for iy, ix in np.ndindex(data.shape):
    data[iy, ix] = sample[iy//2, ix//2]
#画像表示
display(data)

# %%
#パワースペクトル画像表示
display(dft(data))

# %%
data = np.zeros([8,8])
for iy, ix in np.ndindex(data.shape):
    if iy==ix or  iy+ix == 7:
      data[iy, ix] = 1
#画像表示
display(data)

# %%
#パワースペクトル画像表示
display(dft(data))

# %%
data = np.zeros([8,8])
for iy, ix in np.ndindex(data.shape):
    if (ix>0 and ix<7 and iy>0 and iy <7) and (iy==ix or  iy+ix ==7)  :
      data[iy, ix] = 1
#画像表示
display(data)

# %%
#パワースペクトル画像表示
display(dft(data))

# %%
data = np.zeros([8,8])
data[2][3]=data[4][1]=1
#画像表示
display(data)

# %%
#パワースペクトル画像表示
display(dft(data))

# %%
data = np.zeros([8,8])
data[2][6]=data[6][2]=1
#画像表示
display(data)

# %%
#パワースペクトル画像表示
display(dft(data))
